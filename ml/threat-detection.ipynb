# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## importing dataset

# %%
dataset = pd.read_csv("/kaggle/input/random-2/Log Dataset.csv")
dataset
# Out:
#                Timestamp              Source SourceClass      Destination  \
# 0    2023-09-17T01:42:31        192.168.10.5        safe       10.0.0.101
# 1    2023-09-17T01:42:31            10.1.1.1        safe     192.168.10.6
# 2    2023-09-17T01:42:31            10.0.0.2   malicious         10.0.0.3
# 3    2023-09-17T01:42:31  31.15.164.90:27783   malicious     192.168.10.6
# 4    2023-09-17T01:42:31            10.0.0.2   malicious       10.0.0.101
# ..                   ...                 ...         ...              ...
# 495  2023-09-17T01:42:31        192.168.10.5   malicious  166.127.213.176
# 496  2023-09-17T01:42:31       192.168.1.100        safe     192.168.10.6
# 497  2023-09-17T01:42:31         172.16.0.10        safe     192.168.10.6
# 498  2023-09-17T01:42:31          10.0.0.100        safe      192.168.2.6
# 499  2023-09-17T01:42:31         172.16.0.10        safe      192.168.0.2
#
#     DestinationClass       User          Device           EventType  \
# 0               safe    user123  Workstation123   application-usage
# 1               safe  anonymous       ServerABC     system-shutdown
# 2               safe      admin       DeviceXYZ        auth-lockout
# 3               safe    user123  Workstation123      system-failure
# 4               safe      guest       DeviceXYZ         file-access
# ..               ...        ...             ...                 ...
# 495        malicious  anonymous       DeviceXYZ        auth-success
# 496             safe  anonymous       DeviceXYZ     system-shutdown
# 497             safe  anonymous  Workstation123     system-shutdown
# 498             safe      guest       DeviceXYZ  application-errors
# 499             safe      admin  Workstation123  permission-changes
#
#                                            Description       Severity  \
# 0               User 'user123' used application 'App1'  informational
# 1                             System shutdown: Reason2       critical
# 2    User 'admin' locked out after multiple failed ...  informational
# 3           Critical system failure: Error message: 78          error
# 4    File access: Read to file '/path/to/file120.tx...          error
# ..                                                 ...            ...
# 495  Successful login for user 'anonymous' from IP ...  informational
# 496                           System shutdown: Reason2          error
# 497                           System shutdown: Reason6       critical
# 498               Application error: Error message: 96        warning
# 499  User 'admin' changed permissions for file '/pa...       critical
#
#      MLRiskScore
# 0           0.13
# 1           0.33
# 2           0.63
# 3           0.63
# 4           0.50
# ..           ...
# 495         0.63
# 496         0.33
# 497         0.33
# 498         0.27
# 499         0.17
#
# [500 rows x 11 columns]

# %% [markdown]
# ## dropping redundant columns

# %%
dataset.drop(columns=['Source', 'Destination', 'Timestamp', 'Description'], inplace=True)
# dataset

# %% [markdown]
# ## label encoding Source and Destination IPs (safe and malicious)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
columns = ['SourceClass', 'DestinationClass']

dataset[columns] = dataset[columns].apply(le.fit_transform)
dataset
# Out:
#      SourceClass  DestinationClass       User          Device  \
# 0              1                 1    user123  Workstation123
# 1              1                 1  anonymous       ServerABC
# 2              0                 1      admin       DeviceXYZ
# 3              0                 1    user123  Workstation123
# 4              0                 1      guest       DeviceXYZ
# ..           ...               ...        ...             ...
# 495            0                 0  anonymous       DeviceXYZ
# 496            1                 1  anonymous       DeviceXYZ
# 497            1                 1  anonymous  Workstation123
# 498            1                 1      guest       DeviceXYZ
# 499            1                 1      admin  Workstation123
#
#               EventType       Severity  MLRiskScore
# 0     application-usage  informational         0.13
# 1       system-shutdown       critical         0.33
# 2          auth-lockout  informational         0.63
# 3        system-failure          error         0.63
# 4           file-access          error         0.50
# ..                  ...            ...          ...
# 495        auth-success  informational         0.63
# 496     system-shutdown          error         0.33
# 497     system-shutdown       critical         0.33
# 498  application-errors        warning         0.27
# 499  permission-changes       critical         0.17
#
# [500 rows x 7 columns]

# %%
## Severity Column
event_severity_threat = {"informational": 0.1, "warning": 0.7, "error": 0.4, "critical": 0.9}
dataset['Severity'] = dataset['Severity'].replace(event_severity_threat)

## EventType Column
event_type_threat = {
    "auth-failed": 0.8,
    "auth-success": 0.1,
    "auth-lockout": 0.9,
    "network-connected": 0.2,
    "network-disconnected": 0.2,
    "firewall-change": 0.7,
    "dns-queries": 0.3,
    "malware-detection": 0.9,
    "system-shutdown": 0.8,
    "system-restart": 0.7,
    "system-failure": 0.9,
    "application-errors": 0.6,
    "application-usage": 0.2,
    "api-called": 0.4,
    "file-access": 0.5,
    "permission-changes": 0.3,
    "software-update": 0.6
}
dataset['EventType'] = dataset['EventType'].replace(event_type_threat)

## Device Column
devices = {"Workstation123": 1, "DeviceXYZ": 2, "ServerABC": 3}
dataset['Device'] = dataset['Device'].replace(devices)


## User Column
users = {"user123": 1, "guest": 2, "admin": 3, "anonymous":4}
dataset['User'] = dataset['User'].replace(users)

dataset['Access'] = np.random.randint(2, size=500)

dataset
# Out:
#      SourceClass  DestinationClass  User  Device  EventType  Severity  \
# 0              1                 1     1       1        0.2       0.1
# 1              1                 1     4       3        0.8       0.9
# 2              0                 1     3       2        0.9       0.1
# 3              0                 1     1       1        0.9       0.4
# 4              0                 1     2       2        0.5       0.4
# ..           ...               ...   ...     ...        ...       ...
# 495            0                 0     4       2        0.1       0.1
# 496            1                 1     4       2        0.8       0.4
# 497            1                 1     4       1        0.8       0.9
# 498            1                 1     2       2        0.6       0.7
# 499            1                 1     3       1        0.3       0.9
#
#      MLRiskScore  Access
# 0           0.13       0
# 1           0.33       0
# 2           0.63       1
# 3           0.63       1
# 4           0.50       1
# ..           ...     ...
# 495         0.63       1
# 496         0.33       1
# 497         0.33       1
# 498         0.27       1
# 499         0.17       1
#
# [500 rows x 8 columns]

# %% [markdown]
# ## splitting into X and Y

# %%
X = dataset.iloc[:, :-2]
y = dataset.iloc[:,-2]
y2 = dataset.iloc[:,-1]

y2
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 495    1
# 496    1
# 497    1
# 498    1
# 499    1
# Name: Access, Length: 500, dtype: int64

# %% [markdown]
# ## importing catboost regressor

# %%
from catboost import CatBoostRegressor
cat_model = CatBoostRegressor(verbose = False)

# %% [markdown]
# ## importing lightgbm regressor

# %%
import lightgbm as lgb 

lgb_model = lgb.LGBMRegressor()

# %% [markdown]
# ## importing xgboost regressor

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor()

# %% [markdown]
# ## stacking these models together

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import StackingRegressor

base_regressors = [
    ('lightgbm', lgb_model),
    ('catboost', cat_model),
    ('xgboost', xgb_model)
]

meta_regressor = MLPRegressor(hidden_layer_sizes=(400, 200, 100, 50), activation='relu', solver='adam', random_state=42)


model = StackingRegressor(estimators=base_regressors, final_estimator=meta_regressor)
model
# Out:
# StackingRegressor(estimators=[('lightgbm', LGBMRegressor()),
#                               ('catboost',
#                                <catboost.core.CatBoostRegressor object at 0x7c4bbf757940>),
#                               ('xgboost',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             featur...
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...))],
#                   final_estimator=MLPRegressor(hidden_layer_sizes=(400, 200,
#                                                                    100, 50),
#                                                random_state=42))

# %% [markdown]
# ## implementing kfold

# %%
## For Risk Predicion
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)

predictions = np.zeros(len(X))

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    model.fit(X_train, y_train)
    fold_preds = model.predict(X_test)
    fold_r2 = r2_score(y_test, fold_preds)
    print(f"R2 Score for this fold: {fold_r2}")

    predictions[test_index] += fold_preds

final_r2 = r2_score(y, predictions)
print(f"\nOverall R2 Score: {final_r2}")
# Out:
# R2 Score for this fold: 0.9947904819895304
# R2 Score for this fold: 0.9963572563928428
# R2 Score for this fold: 0.9952153360158307
# R2 Score for this fold: 0.9953399556347511
# R2 Score for this fold: 0.9970876556901683
#
# Overall R2 Score: 0.995817550654829

# %%
X
# Out:
#      SourceClass  DestinationClass  User  Device  EventType  Severity
# 0              1                 1     1       1        0.2       0.1
# 1              1                 1     4       3        0.8       0.9
# 2              0                 1     3       2        0.9       0.1
# 3              0                 1     1       1        0.9       0.4
# 4              0                 1     2       2        0.5       0.4
# ..           ...               ...   ...     ...        ...       ...
# 495            0                 0     4       2        0.1       0.1
# 496            1                 1     4       2        0.8       0.4
# 497            1                 1     4       1        0.8       0.9
# 498            1                 1     2       2        0.6       0.7
# 499            1                 1     3       1        0.3       0.9
#
# [500 rows x 6 columns]

# %%
y
# Out:
# 0      0.13
# 1      0.33
# 2      0.63
# 3      0.63
# 4      0.50
#        ...
# 495    0.63
# 496    0.33
# 497    0.33
# 498    0.27
# 499    0.17
# Name: MLRiskScore, Length: 500, dtype: float64

# %%
y2
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 495    1
# 496    1
# 497    1
# 498    1
# 499    1
# Name: Access, Length: 500, dtype: int64

# %%
dataset
new_dataset = dataset.iloc[:,:-1]
new_dataset
# Out:
#      SourceClass  DestinationClass  User  Device  EventType  Severity  \
# 0              1                 1     1       1        0.2       0.1
# 1              1                 1     4       3        0.8       0.9
# 2              0                 1     3       2        0.9       0.1
# 3              0                 1     1       1        0.9       0.4
# 4              0                 1     2       2        0.5       0.4
# ..           ...               ...   ...     ...        ...       ...
# 495            0                 0     4       2        0.1       0.1
# 496            1                 1     4       2        0.8       0.4
# 497            1                 1     4       1        0.8       0.9
# 498            1                 1     2       2        0.6       0.7
# 499            1                 1     3       1        0.3       0.9
#
#      MLRiskScore
# 0           0.13
# 1           0.33
# 2           0.63
# 3           0.63
# 4           0.50
# ..           ...
# 495         0.63
# 496         0.33
# 497         0.33
# 498         0.27
# 499         0.17
#
# [500 rows x 7 columns]

# %%
## Predicting Access Revoked or Not
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)
catboost_model = CatBoostClassifier(iterations=1000, depth=5, learning_rate=0.1, loss_function='Logloss', random_seed=42, verbose = False)

from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)

predictions = np.zeros(len(X))

for train_index, test_index in kf.split(X):
    X_train, X_test = new_dataset.iloc[train_index], new_dataset.iloc[test_index]
    y_train, y_test = y2.iloc[train_index], y2.iloc[test_index]

    catboost_model.fit(X_train, y_train)
    fold_preds = catboost_model.predict(X_test)
    fold_r2 = r2_score(y_test, fold_preds)
#     print(f"R2 Score for this fold: {fold_r2}")

    predictions[test_index] += fold_preds

final_r2 = r2_score(y, predictions)
# print(f"\nOverall R2 Score: {final_r2}")
